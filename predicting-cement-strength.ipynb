# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from sklearn import tree
from sklearn.ensemble.forest import RandomForestClassifier# to import the random forest Model 
from sklearn.metrics import roc_curve, auc                # to import roc curve abd auc metrics for evaluation 
         # grid search is used for hyperparameters-optimization
from sklearn.model_selection import KFold                # cross validation using the kfold algorithm
#from hyperopt import fmin, tpe, hp, STATUS_OK, Trials     # library for hyperparameters-optimization
#=======================================================================================================================
#  Plotting imports
import seaborn as sns                                     # Python graphing library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("train_data(1).csv") #Read file

# %%
df.head() #See contents

# %%
X=df.drop('strength',axis=1) 
y=df['strength']
features=['cement','blast','flyash','water','sp','ca','fa','age']
target=['strength'] 
#Identify the features and target

# %%
from scipy.stats import zscore
Xscaled=X.apply(zscore)
Xscaled_df=pd.DataFrame(Xscaled,columns=df.columns)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(Xscaled, y, test_size=0.3, random_state=1)
#Split the data into training data and test data

# %%
from sklearn.ensemble import RandomForestRegressor
import sklearn.metrics as metrics
#Import the RandomForestRegressor

# %%
model=RandomForestRegressor()
model.fit(X_train,y_train)
#train the model

# %%
y_pred=model.predict(X_valid)
#Validate the model

# %%
model.score(X_train,y_train)

# %%
model.score(X_valid,y_valid)

# %%
X_test=pd.read_csv("test_data.csv")
#read from test file provided

# %%
y_pred1 = model.predict(X_test)
#predict values using the model
y_pred1

# %%
X_test.head()

# %%
submission_df_1 = pd.DataFrame({
                  'Predicted': y_pred1})

# %%
submission_df_1.head(19)
submission_df_1.index.names= ['Id']
submission_df_1.head()

# %%
submission_df_1.to_csv('submission_1.csv', index=True)
#Write your predicted values into a csv file
#this is the file you will be submitting

# %%
read=pd.read_csv("submission_1.csv")
#To see the values written, Read from the csv file

# %%
read.head()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_valid, y_pred))
rms
#finding out the rms value
